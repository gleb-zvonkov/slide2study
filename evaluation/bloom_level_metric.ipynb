# %%
# !pip install openai
# Out:
# Requirement already satisfied: openai in /usr/local/lib/python3.12/dist-packages (1.109.1)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from openai) (4.11.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from openai) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from openai) (0.12.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.12/dist-packages (from openai) (2.11.10)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.12/dist-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.12/dist-packages (from openai) (4.67.1)
# Requirement already satisfied: typing-extensions<5,>=4.11 in /usr/local/lib/python3.12/dist-packages (from openai) (4.15.0)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.12/dist-packages (from anyio<5,>=3.5.0->openai) (3.11)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->openai) (2025.10.5)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->openai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=1.9.0->openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=1.9.0->openai) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=1.9.0->openai) (0.4.2)

# %%
from openai import OpenAI
import ast
import csv
import pandas as pd

# %%
client = OpenAI(api_key="sk-proj-")

# %% [markdown]
# So we have the remember agent. <br>
# Input is the raw text from the slides. <br>
# The output is one remember question. <br>

# %%
system_prompt_remember = """
You are an agent that generates Remember-level questions.
Your input is raw text from lecture slides, but you must NOT refer to the text or say "in the slide" or "mentioned."

Your task:
Create one factual recall question based on the anatomical facts found in the text.

Rules:
- The question must have one clear, factual answer.
- Do NOT ask the learner to explain, compare, or analyze.
- The question must sound like a normal test question.
- Do NOT mention or reference “the slide,” “the text,” or “the passage.”
- Keep the question short and specific.
- Use only information that actually appears in the input text.
- If the text is sparse, pick any clear fact and ask a recall question about it.

Output:
One Remember-level question.
"""

user_prompt = """
Histology is the study of microscopic anatomy, used
to study cells, tissues, and organs, and is foundational
for physiology, biochemistry, and pathology. Cells are the
basic units of the human body, with differentiation leading
to over 200 different cell types. Basic tissues consist of
collections of structurally and functionally similar cells
and their products. The four basic tissue types are
connective tissue, epithelia, muscle, and neural tissue.
These tissues combine to form organs with distinct structure
and function.
"""

questions = []

for i in range(6):
  response = client.chat.completions.create(
      model="gpt-4.1",  # or "gpt-5", etc.
      messages=[
          {"role": "system", "content": system_prompt_remember},
          {"role": "user",   "content": user_prompt}
      ]
  )

  print(response.choices[0].message.content)
  questions.append(response.choices[0].message.content)
# Out:
# What are the four basic tissue types in the human body?
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-2769074052.py in <cell line: 0>()
#      44
#      45   print(response.choices[0].message.content)
# ---> 46   print(response.output_text)
#      47   questions.append(response.choices[0].message.content)
#
# /usr/local/lib/python3.12/dist-packages/pydantic/main.py in __getattr__(self, item)
#     989                     else:
#     990                         # this is the current error
# --> 991                         raise AttributeError(f'{type(self).__name__!r} object has no attribute {item!r}')
#     992
#     993         def __setattr__(self, name: str, value: Any) -> None:
#
# AttributeError: 'ChatCompletion' object has no attribute 'output_text'

# %%
system_prompt_apply = """
You are an agent that generates Apply-level questions.
Your input is raw text from lecture slides.

Your task:
Create one scenario-based question that requires the learner to apply information
from the text to a new but relevant situation.

Rules:
- The question must require using knowledge, not just recalling or explaining it.
- Do NOT analyze, compare, or reference “the slide” or “the text.”
- Keep the question concrete, clear, and solvable from the information provided.
- If the text is sparse, create a simple scenario where the fact must be applied.
- The question must have one correct, logically deducible answer.

Output:
One Apply-level scenario question.
"""

user_prompt = """
Histology is the study of microscopic anatomy, used
to study cells, tissues, and organs, and is foundational
for physiology, biochemistry, and pathology. Cells are the
basic units of the human body, with differentiation leading
to over 200 different cell types. Basic tissues consist of
collections of structurally and functionally similar cells
and their products. The four basic tissue types are
connective tissue, epithelia, muscle, and neural tissue.
These tissues combine to form organs with distinct structure
and function.
"""

questions = []

for i in range(6):
  response = client.chat.completions.create(
      model="gpt-4.1",  # or "gpt-5", etc.
      messages=[
          {"role": "system", "content": system_prompt_apply},
          {"role": "user",   "content": user_prompt}
      ]
  )

  print(response.choices[0].message.content)
  questions.append(response.choices[0].message.content)
# Out:
# A patient has suffered an injury that damaged the tissue responsible for transmitting electrical impulses in their arm. Based on your knowledge of basic tissue types, which type of tissue has likely been affected, and why?
# A researcher is examining a sample from a patient’s liver under a microscope to determine the cause of abnormal function. Which scientific discipline is the researcher using, and which organizational level of the body are they primarily examining?
# A patient has a disease that specifically affects connective tissue. Based on your understanding of the four basic tissue types and their roles, which structures or functions in the patient's body are most likely to be directly impacted by this disease?
# A patient suffers an injury that impairs the function of tissues responsible for transmitting electrical impulses throughout the body. Based on the four basic tissue types, which tissue is most likely affected by the injury?
# A medical researcher is investigating a disease that affects the transmission of electrical signals in the body. Based on your understanding of the four basic tissue types, which type of tissue should the researcher focus on examining to understand how the disease disrupts signal transmission?
# A medical researcher is analyzing a new type of organ found in a rare species. To understand how this organ works, she wants to identify the types of cells and tissues that compose it. Which approach should she use to examine the microscopic anatomy and organization of the organ’s cells, tissues, and any specialized structures?

# %% [markdown]
# Okay now we have an array of raw text from slides.

# %%
# read in data
with open("slide_info.txt", "r") as f:
    data_str = f.read()

data = ast.literal_eval(data_str)

# Extract raw_text fields
raw_text_list = [topic["raw_text"] for topic in data["topics"]]

# %%
def generate_questions(raw_text_list, system_prompt, n=100, filename="questions.csv"):
    examples = []

    with open(filename, "w", newline="") as f:
        writer = csv.writer(f)

        for i in range(n):
            slide_text = raw_text_list[i % len(raw_text_list)]    # for text from one slides

            response = client.chat.completions.create(
                model="gpt-4.1",
                messages=[
                    {"role": "system", "content": system_prompt},
                    {"role": "user", "content": slide_text}
                ]
            )

            question = response.choices[0].message.content.strip()

            writer.writerow([question])
            examples.append(question)

            print(f"{i+1}/{n}: {question}")

    print(f"\nSaved {n} questions to {filename}")
    return examples

# %%
remember_questions = generate_questions(raw_text_list, system_prompt_remember, n=100, filename="remember_questions.csv")
# Out:
# 1/100: What are the four basic tissue types in the human body?
# 2/100: What component makes up most of the volume in connective tissue?
# 3/100: What type of connective tissue protein fibre provides tensile strength?
# 4/100: What is the typical size range of normal lymph nodes?
# 5/100: What are the three common components shared by all connective tissues?
# 6/100: What type of connective tissue has parallel collagen fibers that provide tensile strength along one axis, as found in tendons and ligaments?
# 7/100: What type of cell is found embedded in the extracellular matrix of cartilage?
# 8/100: What type of bone houses red bone marrow, the site of hematopoiesis?
# 9/100: What are the four basic types of tissue in the human body?
# 10/100: What is the main component that determines the properties of connective tissue?
# 11/100: What is the main function of collagen fibers in connective tissue?
# 12/100: What is the normal size range of lymph nodes?
# 13/100: From which embryonic tissue do connective tissue cells originate?
# 14/100: Which type of connective tissue contains parallel collagen fibers and provides tensile strength along one axis, such as in tendons and ligaments?
# 15/100: What type of cells are embedded in the extracellular matrix of cartilage?
# 16/100: What type of bone houses red bone marrow, the site of hematopoiesis?
# 17/100: What are the four basic tissue types in the human body?
# 18/100: What component makes up most of the volume in connective tissue?
# 19/100: What type of connective tissue protein fiber provides tensile strength?
# 20/100: What is the normal size range of lymph nodes in millimeters?
# 21/100: From which embryonic tissue do connective tissue cells originate?
# 22/100: What type of connective tissue contains parallel collagen fibres and provides tensile strength along one axis?
# 23/100: How many subtypes of cartilage are there?
# 24/100: What type of bone contains spaces that house red bone marrow, the site of hematopoiesis?
# 25/100: What are the four basic tissue types in the human body?
# 26/100: What type of cell produces and secretes protein fibres and organic components in connective tissue?
# 27/100: What type of protein fibre in connective tissue imparts tensile strength?
# 28/100: What is the normal size range of lymph nodes in millimeters?
# 29/100: What embryonic tissue gives rise to connective tissue cells?
# 30/100: What type of connective tissue contains densely packed collagen fibers arranged in parallel to provide tensile strength along one axis?
# 31/100: What type of cell is found embedded in the extracellular matrix of cartilage?
# 32/100: What type of bone tissue contains spaces that house red bone marrow?
# 33/100: What are the four basic types of tissue in the human body?
# 34/100: What component determines the properties of connective tissue such as being solid, rubbery, gelatinous, or liquid?
# 35/100: What type of protein fibre in connective tissue provides tensile strength?
# 36/100: What is the normal size range of lymph nodes in millimeters?
# 37/100: What embryonic tissue is the origin of connective tissue cells?
# 38/100: What type of connective tissue contains parallel collagen fibres and provides tensile strength along one axis?
# 39/100: What are the three subtypes of cartilage?
# 40/100: What type of bone marrow is housed in the spaces of spongy bone?
# 41/100: What are the four basic types of tissue in the human body?
# 42/100: What component of connective tissue determines whether it is solid, rubbery, gelatinous, or liquid?
# 43/100: What type of protein fibres in connective tissue provide tensile strength?
# 44/100: What is the normal size range of lymph nodes?
# 45/100: What are the three common components shared by all connective tissues?
# 46/100: What type of connective tissue is composed mostly of adipocytes and functions in energy storage?
# 47/100: What type of cells are embedded in the extracellular matrix of cartilage?
# 48/100: What type of bone contains spaces that house red bone marrow, the site of hematopoiesis?
# 49/100: What are the four basic tissue types in the human body?
# 50/100: What component makes up most of the volume in connective tissue?
# 51/100: What type of protein fibre in connective tissue imparts tensile strength?
# 52/100: What is the normal size range of lymph nodes?
# 53/100: What are the three common components shared by all connective tissues?
# 54/100: What type of connective tissue forms parallel fibres and provides tensile strength along one axis, such as in tendons and ligaments?
# 55/100: What cells are embedded within the extracellular matrix of cartilage?
# 56/100: What type of bone houses red bone marrow, the site of hematopoiesis?
# 57/100: What are the four basic tissue types in the human body?
# 58/100: What determines the properties of connective tissue?
# 59/100: What type of connective tissue fibre provides tensile strength?
# 60/100: What is the normal size range, in millimeters, for lymph nodes?
# 61/100: From which embryonic tissue do connective tissue cells originate?
# 62/100: What type of connective tissue has parallel collagen fibers that provide tensile strength along one axis and is found in tendons and ligaments?
# 63/100: What type of cell is embedded within the extracellular matrix of cartilage?
# 64/100: What type of bone tissue houses red bone marrow, the site of hematopoiesis?
# 65/100: What are the four basic tissue types in the human body?
# 66/100: What component makes up most of the volume in connective tissue?
# 67/100: What protein fibres provide resiliency in connective tissue?
# 68/100: What is the normal size range of lymph nodes in millimeters?
# 69/100: From what embryonic tissue do connective tissue cells originate?
# 70/100: What type of connective tissue has parallel collagen fibers providing tensile strength along one axis?
# 71/100: What type of cells are embedded within the extracellular matrix of cartilage?
# 72/100: What type of bone marrow is housed in the spaces of spongy bone?
# 73/100: What are the four basic tissue types in the human body?
# 74/100: What component makes up most of the volume in connective tissue?
# 75/100: What type of connective tissue protein fiber is responsible for providing tensile strength?
# 76/100: What is the normal size range of lymph nodes in millimeters?
# 77/100: From which embryonic tissue do connective tissue cells originate?
# 78/100: What type of connective tissue has parallel collagen fibers that provide tensile strength along one axis and is found in tendons and ligaments?
# 79/100: What type of cell is embedded within the extracellular matrix of cartilage?
# 80/100: What type of bone houses red bone marrow, the site of hematopoiesis?
# 81/100: What are the four basic types of tissue in the human body?
# 82/100: What type of cell produces and secretes protein fibres and organic components that form the ground substance in connective tissue?
# 83/100: What type of protein fibre in connective tissue imparts tensile strength?
# 84/100: What is the normal size range of lymph nodes?
# 85/100: From which embryonic tissue do connective tissue cells originate?
# 86/100: What type of connective tissue has parallel collagen fibres providing tensile strength along one axis?
# 87/100: What type of cells are embedded in the extracellular matrix of cartilage?
# 88/100: What type of bone houses red bone marrow, the site of hematopoiesis?
# 89/100: What are the four basic types of tissue in the human body?
# 90/100: What component makes up most of the volume in connective tissue?
# 91/100: What type of protein fibre in connective tissue provides tensile strength?
# 92/100: What is the normal size range, in millimeters, of a lymph node?
# 93/100: What is the embryological origin of connective tissue cells?
# 94/100: What type of connective tissue is composed mostly of adipocytes and is supported by a reticular fiber stroma?
# 95/100: What type of cells are embedded in the extracellular matrix of cartilage?
# 96/100: What type of bone houses red bone marrow, the site of hematopoiesis?
# 97/100: What are the four basic tissue types in the human body?
# 98/100: What primarily determines the properties of connective tissue?
# 99/100: What type of protein fibres in connective tissue provide tensile strength?
# 100/100: What is the normal size range of lymph nodes in millimeters?
#
# Saved 100 questions to remember_questions.csv

# %%
system_prompt_understand = """
You are an agent that generates Understand-level questions.
Your input is raw text from lecture slides, which may be short or incomplete.

Your task:
Create one question that requires the learner to demonstrate comprehension
of meaning, concepts, or relationships based on the input text.

Rules:
- The question must require the learner to explain, summarize, interpret, or describe.
- Do NOT ask the learner to apply, solve, or analyze.
- The question must sound like a normal test question.
- Do NOT mention or reference “the slide,” “the text,” or “this passage.”
- Keep the question clear and specific.
- Use only information that appears in the input text.
- If the text is sparse, choose any concept and ask for an explanation or interpretation.

Output:
One Understand-level question.
"""

# %%
understand_questions = generate_questions(raw_text_list, system_prompt_understand, n=100, filename="understand_questions.csv")
# Out:
# 1/100: Explain how the four basic tissue types contribute to the structure and function of organs in the human body.
# 2/100: Explain how the composition and proportions of the extracellular matrix (ECM) influence the physical properties of different types of connective tissue.
# 3/100: Describe how the different components of connective tissue contribute to its overall structure and function.
# 4/100: Explain how lymph nodes help protect the body from disease and infection.
# 5/100: Explain how the components of connective tissue contribute to the differences in characteristics and functions among various connective tissue types.
# 6/100: Summarize the main differences between loose (areolar) connective tissue and dense connective tissue in terms of structure and function.
# 7/100: Describe how the structure and composition of cartilage enable it to provide support to soft tissues while withstanding compressive forces.
# 8/100: Explain how the organic and inorganic components of bone matrix contribute to the overall strength and function of bone.
# 9/100: Explain the relationship between cells, tissues, and organs in the human body, and describe the role of the four basic tissue types.
# 10/100: Describe how the composition and structure of the extracellular matrix (ECM) influence the properties and functions of different types of connective tissue.
# 11/100: Describe how the specific components of connective tissue—protein fibres, ground substance, adhesive glycoproteins, and tissue fluid—contribute to its overall structure and function.
# 12/100: Explain the role of lymph nodes in preventing the spread of disease and infection within the body.
# 13/100: Explain how the composition of cells, protein fibres, and ground substance contributes to the characteristics and functions of different connective tissue types.
# 14/100: Describe the main differences between loose (areolar) connective tissue and dense connective tissue in terms of their structure and functions.
# 15/100: Describe the key structural and functional characteristics of cartilage and explain how its extracellular matrix contributes to its ability to withstand compressive forces.
# 16/100: Explain how the organic and inorganic components of bone matrix contribute to the overall strength and function of bone.
# 17/100: Describe the relationship between cells, basic tissue types, and organs in the human body.
# 18/100: Describe how the composition and proportions of the extracellular matrix (ECM) influence the properties and functions of different types of connective tissue.
# 19/100: Describe how the composition of protein fibres and ground substance in connective tissue contributes to its structural properties and functions.
# 20/100: Describe how lymph nodes help limit the spread of disease and infection within the body.
# 21/100: Explain how the type and proportion of cells, protein fibres, and ground substance influence the characteristics and functions of different connective tissues.
# 22/100: Describe the differences between loose (areolar) connective tissue and dense connective tissue in terms of their structure and functional roles.
# 23/100: Explain how the structure and composition of cartilage enable it to withstand compressive forces while providing support to soft tissues.
# 24/100: Describe the roles of the organic and inorganic components of the bone matrix and explain how their properties contribute to the overall function of bone.
# 25/100: Explain how the four basic tissue types contribute to the formation and function of organs in the human body.
# 26/100: Describe how the composition and proportions of the extracellular matrix (ECM) determine the properties and types of connective tissue.
# 27/100: Describe how the composition of protein fibres and ground substance in connective tissue contributes to its overall characteristics and function.
# 28/100: Describe the role of lymph nodes in preventing the spread of disease and infection within the body.
# 29/100: Explain how the components of connective tissue contribute to its characteristics and functions.
# 30/100: Describe the main differences between loose (areolar) connective tissue and dense connective tissue in terms of their structure and functions.
# 31/100: Explain how the properties of the cartilage extracellular matrix contribute to its ability to withstand compressive forces and support soft tissues without rigidity.
# 32/100: Explain how the composition of the bone matrix contributes to both the strength and the flexibility of bone.
# 33/100: Explain how the four basic tissue types contribute to the structure and function of organs in the human body.
# 34/100: Describe how the composition and proportions of the extracellular matrix influence the properties of different types of connective tissue.
# 35/100: Describe how the different components of connective tissue—protein fibres, ground substance, adhesive glycoproteins, and tissue fluid—contribute to its structure and function.
# 36/100: Describe the process by which lymph is filtered and explain the role of lymph nodes in limiting the spread of disease and infection.
# 37/100: Explain how the variation in the type and proportion of cells, protein fibres, and ground substance influences the characteristics and functions of different connective tissue types.
# 38/100: Describe the main differences between loose (areolar) connective tissue and dense connective tissue, including their structure and functions.
# 39/100: Explain how the extracellular matrix enables cartilage to withstand compressive forces and discuss why cartilage has limited capacity for repair.
# 40/100: Describe the roles of organic and inorganic components in the bone matrix and explain how their properties contribute to the function of bone tissue.
# 41/100: Explain how the four basic tissue types work together to form organs with distinct structure and function.
# 42/100: Describe how the structure and composition of the extracellular matrix (ECM) influence the properties and functions of different types of connective tissue.
# 43/100: Describe how the unique composition of protein fibres and ground substance components in connective tissue contribute to its overall characteristics and functions.
# 44/100: Explain how lymph nodes contribute to limiting the spread of disease and infection in the body.
# 45/100: Explain how the variation in type and proportion of cells, protein fibres, and ground substance contributes to the characteristics and functions of different types of connective tissue.
# 46/100: Describe the structural differences between loose (areolar) connective tissue and dense connective tissue, and explain how these differences relate to their respective functions.
# 47/100: Describe how the structure and composition of cartilage allow it to provide support to soft tissues while remaining flexible and resilient.
# 48/100: Describe how the composition of the bone matrix contributes to both the strength and flexibility of bone tissue.
# 49/100: Explain how the four basic tissue types contribute to the structure and function of organs in the human body.
# 50/100: Explain how the composition and properties of the extracellular matrix (ECM) influence the characteristics of different types of connective tissue.
# 51/100: Explain how the different components of connective tissue contribute to its structure and function.
# 52/100: Describe the role of lymph nodes in the lymphatic system and explain how they help limit the spread of disease and infection.
# 53/100: Explain how the type and proportion of cells, protein fibres, and ground substance contribute to the characteristics and functions of different connective tissue types.
# 54/100: Describe the main differences between loose (areolar) connective tissue and dense connective tissue, including their structure and functions.
# 55/100: Describe the structural and functional characteristics of cartilage that enable it to provide support to soft tissues while remaining pliable and resilient.
# 56/100: Explain how the composition and arrangement of bone matrix contribute to both the strength and flexibility of bone tissue.
# 57/100: Explain how the four basic tissue types contribute to the structure and function of organs.
# 58/100: Describe how the composition and proportions of the extracellular matrix (ECM) influence the properties of different types of connective tissue.
# 59/100: Describe how the unique composition of protein fibres and ground substance in connective tissue contributes to its overall characteristics and functions.
# 60/100: Explain how lymph nodes help limit the spread of disease and infection in the body.
# 61/100: Explain how the components of connective tissue contribute to its characteristics and functions.
# 62/100: Describe the differences between loose (areolar) connective tissue and dense connective tissue in terms of their structure and function.
# 63/100: Explain how the properties of the cartilage extracellular matrix contribute to its function and its ability to withstand compressive forces.
# 64/100: Explain how the organic and inorganic components of the bone matrix contribute to the overall strength and function of bone tissue.
# 65/100: Explain how the four basic tissue types contribute to the structure and function of organs in the human body.
# 66/100: Describe how the composition and properties of the extracellular matrix (ECM) influence the characteristics of different types of connective tissue.
# 67/100: Describe how the composition of protein fibres, ground substance, and tissue fluid in connective tissue contributes to its structural and functional properties.
# 68/100: Describe the role of lymph nodes in preventing the spread of disease and infection in the body.
# 69/100: Explain how the type and proportion of cells, protein fibres, and ground substance contribute to the characteristics and functions of different connective tissues.
# 70/100: Describe the main differences between loose (areolar) connective tissue and dense connective tissue, including their composition and functional roles.
# 71/100: Describe how the composition and structure of cartilage's extracellular matrix contribute to its ability to withstand compressive forces and support soft tissues.
# 72/100: Describe how the composition and structure of bone matrix contribute to its strength and function.
# 73/100: Explain the relationship between cells, tissues, and organs in the human body.
# 74/100: Describe how the composition and structure of the extracellular matrix (ECM) influence the properties and functions of different types of connective tissue.
# 75/100: Describe how the composition of protein fibres and ground substance in connective tissue contributes to its overall function and physical properties.
# 76/100: Explain how lymph nodes function to limit the spread of disease and infection within the lymphatic system.
# 77/100: Explain how the type and proportion of cells, protein fibres, and ground substance contribute to the characteristics and functions of different connective tissue types.
# 78/100: Describe the main differences between loose (areolar) connective tissue and dense connective tissue, and explain the functional significance of these differences.
# 79/100: Describe how the structure and composition of cartilage enable it to withstand compressive forces and provide support to soft tissues.
# 80/100: Describe the roles of the organic and inorganic components of the bone matrix in providing bone with its mechanical properties, and explain how compact and spongy bone differ in their structural arrangement and functions.
# 81/100: Explain the relationship between cells, tissues, and organs in the human body, and describe the four basic types of tissues.
# 82/100: Explain how variations in the composition and proportions of the extracellular matrix (ECM) influence the properties of different types of connective tissue.
# 83/100: Explain how the unique composition of protein fibres and ground substance in connective tissue contributes to its overall function and characteristics.
# 84/100: Describe the role of lymph nodes in preventing the spread of disease and infection within the body.
# 85/100: Explain how the type and proportion of cells, protein fibres, and ground substance influence the characteristics and functions of different connective tissues.
# 86/100: Explain the main differences between loose (areolar) connective tissue and dense connective tissue in terms of their structure and function.
# 87/100: Explain how the unique properties of cartilage, including its extracellular matrix composition and avascular nature, contribute to both its function and its limited capacity for repair.
# 88/100: Describe the roles of the organic and inorganic components of the bone matrix and explain how their composition contributes to the overall properties and functions of bone tissue.
# 89/100: Explain the relationship between cells, tissues, and organs in the context of the human body.
# 90/100: Explain how the composition and proportions of the extracellular matrix (ECM) contribute to the different properties of connective tissues such as bone, cartilage, and blood.
# 91/100: Explain how the composition of protein fibres and ground substance in connective tissue contributes to its function and mechanical properties.
# 92/100: Explain how lymph nodes help limit the spread of disease and infection in the body.
# 93/100: Explain how the type and proportion of cells, protein fibres, and ground substance contribute to the characteristics and functions of different connective tissue types.
# 94/100: Describe the key differences between loose (areolar) connective tissue and dense connective tissue in terms of their structure and primary functions.
# 95/100: Explain how the extracellular matrix enables cartilage to withstand compressive forces and describe why cartilage has a limited capacity for repair.
# 96/100: Describe the roles of both the organic and inorganic components of the bone matrix, and explain how these contribute to the properties and functions of bone tissue.
# 97/100: Explain how the four basic tissue types contribute to the structure and function of organs in the human body.
# 98/100: Describe how the composition and proportions of the extracellular matrix (ECM) influence the properties and functions of different types of connective tissue.
# 99/100: Describe how the composition and functions of collagen fibres, elastic fibres, ground substance, adhesive glycoproteins, and tissue fluid contribute to the properties and roles of connective tissue.
# 100/100: Describe the role of lymph nodes in preventing the spread of disease and infection throughout the body.
#
# Saved 100 questions to understand_questions.csv

# %%
system_prompt_apply = """
You are an agent that generates Apply-level questions.
Your input is raw text from lecture slides.

Your task:
Create one scenario-based question that requires the learner to apply information
from the text to a new but relevant situation.

Rules:
- The question must require using knowledge, not just recalling or explaining it.
- Do NOT analyze, compare, or reference “the slide” or “the text.”
- Keep the question concrete, clear, and solvable from the information provided.
- If the text is sparse, create a simple scenario where the fact must be applied.
- The question must have one correct, logically deducible answer.

Output:
One Apply-level scenario question.
"""

# %%
apply_questions = generate_questions(raw_text_list, system_prompt_apply, n=100, filename="apply_questions.csv")
# Out:
# 1/100: A patient suffers an injury that damages only the muscle tissue in their arm, but leaves the other tissue types intact. Based on your understanding of basic tissue types, what types of cell structure and function would be primarily affected in this injury, and which three other basic tissue types would remain largely unaffected?
# 2/100: A patient presents with a connective tissue disorder where the ground substance of the extracellular matrix does not properly bind tissue fluid, leading to unusually loose and watery tissue. Based on your knowledge of connective tissue structure, which property or function of the tissue is most likely to be compromised in this patient, and why?
# 3/100: A patient suffers a connective tissue injury that results in decreased synthesis of collagen fibres but normal production of elastic fibres and ground substance. Predict how the mechanical properties of their connective tissue would be affected, and describe a likely physical symptom they might experience as a result.
# 4/100: A doctor examines a patient who has a swollen, tender lymph node in their neck following a throat infection. Explain how the lymphatic system is helping to limit the spread of infection in this patient.
# 5/100: A researcher is developing an artificial tissue patch to repair damage in an organ lining. To ensure compatibility, they need to select cells with the same embryological origin as connective tissue. Based on this requirement, which type of cell should the researcher use to line the patch: typical epithelial cells or mesothelial cells? Explain your reasoning.
# 6/100: A patient suffers a deep skin laceration that damages the tissue forming the dermis, exposing the area to significant mechanical stress from multiple directions. Which type of connective tissue will primarily be involved in providing structural support and resistance to this multidirectional stress during wound healing?
# 7/100: A patient suffers an injury to the ear’s elastic cartilage, causing minor damage. Explain why this cartilage will likely heal slowly and describe how chondrocytes in the damaged area obtain the nutrients they need for repair.
# 8/100: A patient experiences a genetic disorder that results in the decreased production of collagen fibers in bone tissue, while mineral content remains normal. Based on the composition and function of bone matrix components, what specific mechanical property of this patient’s bones would most likely be compromised, and what potential consequence could arise from this change?
# 9/100: A scientist is investigating a newly discovered organ in the human body and observes that it is primarily made up of tightly packed cells forming barriers and linings, along with some supporting tissues and nerve fibers. Based on this observation, which primary tissue types should the scientist expect to find predominantly in this organ, and how does this relate to its potential function?
# 10/100: A patient suffers an injury that causes excessive swelling in their connective tissue due to fluid buildup. Based on your knowledge of connective tissue structure, which component would you target to reduce the swelling, and what property of connective tissue makes this an effective strategy?
# 11/100: A patient sustains a deep cut that severs the skin and underlying connective tissue. During healing, the newly formed tissue at the site is abnormally soft and easily compressed. Based on the properties of connective tissue components, which element is most likely deficient in the new tissue, and why does its deficiency lead to the observed softness?
# 12/100: A patient has a bacterial infection in the right arm. Explain how the lymphatic system would help prevent the spread of this infection to the rest of the body.
# 13/100: A researcher is developing a tissue graft and wants to ensure it mimics the natural origin and composition of connective tissues. If she uses cells derived from mesenchyme and adjusts the proportions of protein fibres and ground substance, what key structural and functional property of the graft can she influence by making the ground substance more abundant than protein fibres?
# 14/100: A patient suffers a puncture wound to the skin that requires healing with both strength and flexibility. Which type or types of connective tissue would most likely be active in repairing this wound, and how would their structural characteristics contribute to the healing process?
# 15/100: A patient suffers a knee injury that causes damage to the hyaline cartilage covering the ends of their femur. Considering the properties of cartilage, explain why the recovery and repair of this tissue would be slower than the recovery of a bone fracture in the same area.
# 16/100: A young athlete sustains a bone fracture. During healing, it is important that the bone regains both its flexibility to withstand tension and its strength to bear weight. Explain how deficiencies in vitamin C or calcium during recovery might differently affect the bone repair process, based on the components and functions of the bone matrix.
# 17/100: A pathologist is examining a damaged area in the intestine where the normal lining has been destroyed and needs to recommend the type of tissue best suited to replace this lining so it can protect underlying structures and facilitate absorption. Which of the four basic tissue types should the pathologist recommend for regenerating the intestine’s lining?
# 18/100: A patient suffers a connective tissue injury that results in a loss of the protein fibers within the extracellular matrix, while the ground substance remains unchanged. Predict how the physical properties of the affected connective tissue would change, and explain what functional consequences this might have for tissues such as tendons or cartilage.
# 19/100: A patient sustains a skin injury that requires a tissue graft capable of withstanding repeated stretching and quickly returning to its original shape. Based on the functions of connective tissue components, which type of protein fibre should be most abundant in the graft material, and why?
# 20/100: A patient develops a bacterial infection in a wound on their lower leg. Explain how the lymphatic system would help limit the spread of this infection throughout the body.
# 21/100: A researcher is engineering a new tissue graft that must closely resemble natural connective tissue in both structure and function. Which components should the researcher prioritize in their design to ensure the graft behaves like genuine connective tissue, and why?
# 22/100: A patient suffers a shoulder injury that results in a torn tendon. Based on the properties of connective tissues, explain which type of connective tissue is primarily affected by this injury and why its structural composition makes it suitable for this function.
# 23/100: A young athlete sustains a knee injury that compresses the meniscus, which is composed primarily of fibrocartilage. Considering the properties and structure of cartilage tissue, explain why the meniscus is able to absorb the compressive force during the injury and why recovery from such injuries tends to be slow.
# 24/100: A young athlete suffers a fracture that damages the spongy bone at the end of his femur, resulting in reduced red blood cell production. Explain how the unique features of spongy bone contribute to these hematopoietic complications, and why a similar injury to the compact bone along the shaft might affect him differently.
# 25/100: A researcher discovers a previously unknown organ in the human body and wants to determine how it functions. What steps should the researcher take to analyze this organ's tissues and relate their structure to the organ’s function?
# 26/100: A patient sustains an injury that disrupts the production of the ground substance component of their connective tissue, but the protein fibers remain unaffected. Predict how this change would affect the properties of the patient’s connective tissue and explain why.
# 27/100: A patient experiences swelling (edema) in their ankle after an injury. Explain how the components of connective tissue—specifically proteoglycans in the ground substance and the balance of tissue fluid volume—contribute to both the development and potential resolution of this edema.
# 28/100: A patient discovers a firm, enlarged lymph node in their neck during a routine self-exam. Based on your understanding of lymphatic drainage and lymph node function, explain why this lymph node might feel enlarged after the patient recently recovered from a throat infection.
# 29/100: A researcher is developing an artificial tissue graft and needs it to mimic the structural support and flexibility of natural connective tissue. Which components should they adjust in their design to achieve different characteristics such as elasticity or rigidity, and why?
# 30/100: A patient suffers an injury that stretches a tendon without tearing it. Which specific type of connective tissue is primarily responsible for the tendon's ability to withstand the pulling force, and what structural feature allows it to do so?
# 31/100: A patient suffers an injury to their knee resulting in damage to the articular cartilage covering the ends of the femur. Given the characteristics and repair mechanisms of cartilage, what challenges would the patient most likely face during recovery, and why?
# 32/100: A patient is diagnosed with a genetic disorder that leads to defective collagen synthesis in their bones. Based on this information, what mechanical property of their bones is most likely to be compromised, and what type of injury would they be more susceptible to as a result?
# 33/100: A patient has suffered an injury that damages only the connective tissue in a particular organ, while the epithelia, muscle, and neural tissues remain intact. Based on your understanding of tissue types, what general functions or roles within the organ are most likely to be disrupted as a result of this injury?
# 34/100: A patient suffers an injury that results in the breakdown of the protein fibers within their cartilage. Based on your understanding of connective tissue structure and function, predict how this change would affect the properties of the affected cartilage and explain why.
# 35/100: A patient presents with swollen ankles after standing for long periods, indicating fluid accumulation in the connective tissue. Which component of the extracellular matrix is primarily responsible for resisting this compression caused by the excess tissue fluid, and how does it perform this function?
# 36/100: A patient presents with a rapidly enlarging mass in the left axilla. Explain how the lymphatic system would help limit the spread of any infectious agents or abnormal cells originating from this area before they enter the bloodstream.
# 37/100: A patient is recovering from surgery and is experiencing delayed wound healing. Laboratory analysis shows an abnormality in the ground substance production within their connective tissue. Based on this information, what direct effect might this abnormality have on the wound healing process?
# 38/100: A patient sustains an injury that requires surgical attachment of a muscle to a bone. Which type of connective tissue would most effectively provide the necessary tensile strength for this attachment, and why?
# 39/100: A patient suffers damage to the cartilage in their knee joint, leading to impaired movement and pain. Given that cartilage is avascular and relies on nutrient diffusion, what challenge will this pose for the healing process, and why might repair be particularly slow in this tissue?
# 40/100: A patient suffers a genetic disorder that reduces the production of collagen fibers in their bones. Based on the composition and functions of bone matrix components, what mechanical property of their bones would be most affected, and what kind of injury would they be more prone to experiencing?
# 41/100: A patient is experiencing muscle weakness and shows signs of impaired nerve function, but their connective and epithelial tissues appear unaffected. Based on your understanding of tissue types, which two basic tissue types are most likely directly involved in the patient's symptoms, and why?
# 42/100: A patient suffers an injury that causes the ground substance in their cartilage to become less rubbery and more liquid-like. How might this change affect the function of the cartilage in their joints?
# 43/100: A patient is experiencing swelling in their ankle due to increased tissue fluid volume. Explain how the properties of proteoglycans within the ground substance help resist compression in the swollen connective tissue.
# 44/100: A patient presents with swelling and tenderness in their left axilla, and physical examination reveals an enlarged lymph node in that area. Given that lymph from the left upper limb drains through axillary lymph nodes before returning to the bloodstream, explain how this lymph node enlargement could be related to a local infection in the left arm and the function of lymph nodes in this process.
# 45/100: A patient experiences poor healing and loss of elasticity in their skin following an injury. Based on your understanding of connective tissue components and their embryological origins, which component is most likely deficient or malfunctioning in this patient, and why?
# 46/100: A surgeon needs to reinforce a repaired tendon to ensure it can withstand strong, unidirectional pulling forces during movement. Which specific type of connective tissue should the surgeon use to achieve the necessary tensile strength, and why?
# 47/100: A patient suffers an injury to their knee that results in damage to the articular cartilage covering the ends of the femur. Considering the properties of cartilage tissue, explain why the healing process in this area is likely to be slow, and identify the specific mechanisms by which cartilage receives nutrients necessary for repair.
# 48/100: A patient has a genetic disorder that significantly reduces the production of collagen fibers in their bone tissue. Based on your understanding of bone matrix composition and function, what change in bone properties would you expect, and what clinical symptoms might result from this?
# 49/100: A researcher is examining a biopsy sample to determine which basic tissue types are present in a newly discovered organ. She observes cells that transmit electrical impulses, others that contract to produce movement, and some that are tightly joined to form protective layers. Based on her observations, which three basic tissue types has she identified in her sample?
# 50/100: A patient is found to have a genetic disorder that severely reduces their connective tissue cells’ ability to secrete protein fibres, while secretion of organic molecules and fluid binding remains normal. Which property of their connective tissues would most likely be affected, and how might this manifest in the patient’s body?
# 51/100: A patient develops localized swelling (edema) after an ankle injury. Explain how the properties of proteoglycans in the connective tissue extracellular matrix influence the accumulation and retention of tissue fluid in this swollen area.
# 52/100: A patient presents with a swollen, palpable lymph node in the axilla after sustaining a minor skin infection on their forearm. Explain how this swelling is related to the body's defense system and predict what would likely happen if the lymphatic vessels from the forearm were blocked.
# 53/100: A researcher is developing an artificial tissue implant designed to mimic the lining of blood vessels. Based on the origin and classification of tissue types, which embryonic tissue should the researcher use to derive the necessary surface-lining cells for the implant, and why?
# 54/100: A patient suffers a torn ligament in their knee. During the healing process, which type of connective tissue must regenerate to restore the ligament's strength, and what structural feature of this tissue makes it suited to its function?
# 55/100: A young athlete suffers a knee injury that results in damage to the meniscus, which is composed primarily of cartilage. After the injury, the cartilage shows limited healing over several months. Based on the characteristics of cartilage, explain why the repair process in this tissue is slow and what factors in its structure contribute to this slow healing.
# 56/100: A patient has a genetic disorder that causes their bone matrix to lack sufficient collagen fibers but has normal mineralization. What mechanical property of their bones is most likely to be reduced as a result, and what symptom might this cause?
# 57/100: A biopsy sample from a patient's stomach is being examined under the microscope. The sample shows layers that include cells specialized for rapid communication, bundled contractile cells, and sheets of tightly connected cells covering surfaces. Based on your understanding of basic tissue types, how should you classify each of these layers?
# 58/100: A patient suffers an injury that causes the replacement of cartilage in their knee with ordinary connective tissue. Based on the differences in extracellular matrix composition, what change in the knee's physical properties would you expect after this replacement, and why?
# 59/100: A patient presents with swollen ankles after standing for long periods, indicating an increase in tissue fluid volume. Based on your knowledge of connective tissue components, explain which properties of the extracellular matrix help resist or contribute to this swelling, and predict what might happen if the proteoglycan content in the ground substance is abnormally low.
# 60/100: A patient develops a localized bacterial infection in the skin of their forearm. Explain how the lymphatic system would help prevent the spread of this infection to the rest of the body.
# 61/100: A researcher is developing a synthetic tissue to line blood vessels and wants the new tissue to mimic the properties of natural vessel linings as closely as possible. Based on your knowledge of tissue origins and components, which embryological origin and main tissue components should the researcher replicate to achieve this goal?
# 62/100: A surgeon is planning to repair a torn tendon in a patient’s shoulder. Which type of connective tissue should the surgeon use for the graft material to ensure it provides the necessary tensile strength along the direction of muscle pull, and why?
# 63/100: A patient suffers a knee injury that results in damage to the cartilage covering the ends of the femur and tibia. Given the characteristics and function of cartilage tissue, explain why the healing process in this area is likely to be slow, and describe how nutrients will reach the chondrocytes during recovery.
# 64/100: A patient has a genetic disorder that causes a significant reduction in collagen fiber production within their bones, while mineralization processes remain normal. What changes in bone properties would most likely be observed in this patient, and what symptoms might result from these changes?
# 65/100: A biomedical researcher is designing an artificial organ and needs to ensure it can contract to pump fluid while also transmitting electrical signals rapidly between cells. Which two basic tissue types should the researcher incorporate into the design to achieve these functions?
# 66/100: A patient suffers an injury that causes their cartilage to become more rigid and less flexible than normal. Based on the role of the extracellular matrix (ECM) in determining tissue properties, which component of the cartilage ECM is most likely altered to cause this change, and why?
# 67/100: A patient suffers a ligament injury that results in decreased tensile strength and reduced ability to resist stretching forces. Based on your knowledge of connective tissue structure, which component is most likely affected, and how would this impact the tissue's function?
# 68/100: A patient presents with a swollen, tender lump in the groin area following a recent foot infection. Explain how the lymphatic system is involved in the detection and limitation of this infection’s spread, and identify what the swelling in the groin most likely represents.
# 69/100: A researcher is engineering a new type of artificial tissue designed to function as a barrier lining blood vessels. To ensure the engineered tissue closely mimics the natural embryological origin and functional properties of blood vessel linings, which cell type should the researcher focus on incorporating, and from which embryonic tissue should these cells be derived?
# 70/100: A patient suffers a deep cut to the skin over their shoulder that later heals with a thick, immobile scar. Which type of connective tissue is most likely responsible for the tensile strength and firmness of the scar tissue, and why?
# 71/100: A patient suffers a minor tear in the cartilage of their knee joint. Considering the properties of cartilage, explain why their recovery is likely to be slower than if they had a similar injury to nearby vascularized tissue.
# 72/100: A patient is recovering from an accident in which their bones were subjected to significant pulling and twisting forces. Later, laboratory tests reveal a deficiency in collagen fiber production. Based on bone matrix composition, what functional issue would you expect the patient's bones to have as a result of this deficiency?
# 73/100: A medical researcher is studying a newly discovered gland in the human body. To determine how it functions and what type of cells make up the gland, the researcher plans to examine thin tissue sections under a microscope. Which scientific field should the researcher use to analyze the microscopic structure and cellular composition of the gland, and why is this approach important for understanding organ function?
# 74/100: A patient has a genetic mutation that prevents their connective tissue cells from properly secreting protein fibres into the extracellular matrix. Predict how this mutation would likely affect the structure and function of their connective tissues, and give one example of how this might present in their body.
# 75/100: A patient suffers from a mutation that causes a deficiency in the production of proteoglycans in their connective tissue. What symptoms related to connective tissue function would you expect this patient to experience, and why?
# 76/100: A patient presents with enlarged, palpable lymph nodes in their neck and reports a recent sore throat. Explain how the lymphatic system is helping to limit the spread of infection in this situation, and why the lymph nodes have become enlarged.
# 77/100: A patient receives a skin graft, and the transplanted tissue includes both connective tissue and the overlying endothelial covering of blood vessels. If complications arise due to differences in embryological origin between tissue types, which parts of the graft are most likely to be compatible, and why?
# 78/100: A surgeon is planning to reconstruct a torn tendon in a patient’s arm. Considering the need for strong, unidirectional tensile strength in the repair, which type of connective tissue would be most suitable for the graft material, and why?
# 79/100: A patient suffers a minor ear injury that damages the cartilage in the external ear (pinna). Given the properties of cartilage tissue described, explain why their ear is able to retain its shape after being bent and why recovery from injury in this area is expected to be slow.
# 80/100: A patient suffers a genetic disorder that drastically reduces the production of collagen fibers in their bones. Based on the composition and roles of the organic and inorganic components of bone matrix, what physical property of their bones is most likely to be affected, and what kind of injury would they be especially susceptible to?
# 81/100: A scientist discovers a new organ in the human body that performs both rapid electrical communication and contraction in response to stimuli. Based on your understanding of tissue types and their functions, which two basic tissue types must this organ contain, and why?
# 82/100: A patient is diagnosed with a connective tissue disorder that causes the extracellular matrix in their cartilage to lose its rubbery texture and become more liquid-like. Based on your knowledge of connective tissue composition, what change in the ECM is most likely responsible for this alteration, and how would it affect the tissue's properties?
# 83/100: A patient suffers a sprained ankle, resulting in localized swelling. Based on your knowledge of connective tissue components, explain how the properties of proteoglycans in the ground substance contribute to the ankle’s resistance to compression during this swelling.
# 84/100: A patient develops swelling and tenderness in the axilla after a localized bacterial infection in their arm. Explain how the lymphatic system responds to this infection and why the axillary lymph nodes become enlarged and palpable in this scenario.
# 85/100: A researcher is developing an artificial tissue graft intended to line internal body cavities. She wants to ensure that the graft replicates the embryological origin and common structural components of the cells lining natural body cavities. Which embryonic tissue should she mimic in her design, and what components must be present in the artificial connective tissue to maintain its typical structure?
# 86/100: A patient suffers a deep cut to the ankle, severing a structure that attaches muscle to bone and is subject to high tension when walking. Over time, the wound heals, but the repaired structure is weaker and more prone to injury. Which type of connective tissue was most likely damaged, and what primary functional property does this tissue provide in its normal state?
# 87/100: A patient suffers a knee injury in which the cartilage covering the ends of their femur is damaged. Explain how the unique properties of cartilage tissue will impact the rate and manner in which this tissue repairs itself compared to well-vascularized tissues like bone.
# 88/100: A patient suffers a genetic disorder that significantly reduces the amount of collagen in their bone osteoid but leaves the mineral content unchanged. Predict how this condition would most likely affect the physical properties of the patient's bones, and explain what type of bone injuries they would be particularly susceptible to.
# 89/100: A medical researcher is examining a biopsy sample to identify the cause of a patient's muscle weakness. Which tissue type should the researcher focus on when looking for abnormalities related to voluntary movement?
# 90/100: A patient has a genetic disorder that prevents their connective tissue cells from producing normal levels of protein fibers in the extracellular matrix. Predict how this deficiency would affect the physical properties of their bone, cartilage, and blood tissues.
# 91/100: A patient presents with swelling in their ankles, which is diagnosed as edema. Based on your understanding of connective tissue components, explain how an increase in tissue fluid volume could affect the consistency and function of the connective tissue matrix in the affected area.
# 92/100: A patient presents with a swollen, tender lymph node in the groin area following a skin infection on their lower leg. Explain how the lymphatic system would work to limit the spread of the infection from the leg to the rest of the body.
# 93/100: A researcher is engineering a replacement blood vessel using tissue culture. To ensure the lining of the artificial vessel is as true to natural tissue as possible, she must select the appropriate cell type for the vessel's interior. Based on embryological origin, which cell type should she choose to line the inside of the vessel, and why?
# 94/100: A patient suffers a deep cut that severs a tendon in their hand. During surgical repair, the doctor needs to choose an appropriate graft material to restore strength and function to the tendon. Based on the properties of connective tissues, which type of connective tissue would be most appropriate for the graft, and why?
# 95/100: A young athlete suffers a knee injury where a piece of cartilage within the joint is torn. Based on the structure and properties of cartilage, explain why this tissue is slow to heal and describe how its extracellular matrix supports the joint during movement.
# 96/100: A patient is recovering from a fracture and is advised to consume a diet rich in calcium and vitamin D. Explain how an adequate supply of calcium would specifically affect the mineralization process of bone matrix during healing, and what property of bone would be most directly restored by this process.
# 97/100: A patient sustains an injury that affects only one of the four basic tissue types in their arm, resulting in loss of voluntary movement but with preserved sensation, skin integrity, and connective structure. Based on your understanding of tissue types, which tissue type is most likely affected, and why?
# 98/100: A researcher is developing a new biomaterial for artificial cartilage. To mimic the properties of natural cartilage, which component of connective tissue should the researcher primarily focus on modifying, and why?
# 99/100: A patient presents with swelling in the lower legs following an ankle sprain, resulting from an accumulation of excess tissue fluid in the affected area. Considering the roles of proteoglycans and the ground substance in connective tissue, explain how the properties of the extracellular matrix contribute to both the development of this swelling and the tissue’s ability to resist compression during the injury.
# 100/100: A patient presents with swollen and tender lymph nodes in the groin after suffering a small cut on their foot. Explain how the lymphatic system would respond to this injury and why the lymph nodes in the groin are affected.
#
# Saved 100 questions to apply_questions.csv

# %% [markdown]
# Now lets create an evaultor using our anatomy data, which is question labeled with remember, understand, apply.
# First we read in anatomy class data.

# %%
df = pd.read_csv("questions_labeled.csv", encoding="latin-1")

questions = df["question"].tolist()
labels = df["label"].tolist()

# %% [markdown]
# Now we create an evaluator agent.

# %%
system_prompt_evaluator = """
You are an agent that classifies a question as either:
- remember
- understand
- apply

Remember: asks for simple factual recall.
Understand: asks to explain, describe, or interpret a concept.
Apply: uses a scenario where knowledge must be used to solve something.

Read the question and output only one label:
"remember", "understand", or "apply".
"""

# %%
def classify_questions(question_list):
    predicted_questions = []
    predicted_labels = []

    for q in question_list:
        response = client.chat.completions.create(
            model="gpt-4.1",
            messages=[
                {"role": "system", "content": system_prompt_evaluator},
                {"role": "user", "content": q}
            ]
        )

        label = response.choices[0].message.content.strip().lower()

        predicted_questions.append(q)
        predicted_labels.append(label)

        # print(f"Question: {q}")
        # print(f" → {label}\n")

    return predicted_questions, predicted_labels

# %% [markdown]
# First lets runs the classifier on our anatomy data.

# %%
questions, gpt_labels= classify_questions(questions)
# Out:
# Question: In which plane could ONLY the right lung be seen in a thorax section?
#  → apply
#
# Question: A radiologist wants to isolate the right lung in a thoracic image. Which imaging plane should they choose?
#  → apply
#
# Question: Which imaging study produces detailed soft-tissue images without ionizing radiation?
#  → remember
#
# Question: Describe why we would use an MRI overt a CT scan?
#  → understand
#
# Question: A patient needs detailed soft-tissue imaging but should avoid radiation. Which imaging test should be chosen for this situation?
#  → apply
#
# Question: What term describes the position of the arms relative to the thorax?
#  → remember
#
# Question: Which cell junction permits molecular and ionic movement between adjacent cells?
#  → remember
#
# Question: Describe how certain cell junctions allow communication or passage of molecules between neighboring cells.
#  → understand
#
# Question: What epithelium appears stratified but has every cell touching the basement membrane?
#  → remember
#
# Question: Explain how a tissue can appear stratified even though all of its cells make contact with the basement membrane.
#  → understand
#
# Question: What molecule provides tensile strength in connective tissue?
#  → remember
#
# Question: A patient has a genetic defect that reduces the body's ability to produce strong protein fibers in connective tissue. How would this effect tissue strenght.
#  → understand
#
# Question: What component occupies the largest volume in loose (areolar) connective tissue?
#  → remember
#
# Question: What bone matrix component provides compressional strength?
#  → remember
#
# Question: Explain how certain components of the bone matrix allow bone to resist compression.
#  → understand
#
# Question: A patient has a disorder that reduces the inorganic component of their bone matrix. How would this affect the boneÕs ability to withstand compressional forces?
#  → apply
#
# Question: Where is toluidine blue staining (for myelin) highest and most homogeneous?
#  → remember
#
# Question: Describe why certain regions of nervous tissue show stronger and more uniform toluidine blue staining for myelin?
#  → understand
#
# Question: How does the spine adjust when carrying a heavy load in a backpack?
#  → understand
#
# Question: Explain how the spine changes its curvature when the body carries weight, such as a heavy backpack.
#  → understand
#
# Question: A student carries a heavy backpack that shifts their center of gravity backward. How will the spine adjust its curvature to maintain balance?
#  → apply
#
# Question: What structure changes shape to allow movement between vertebrae?
#  → remember
#
# Question: Describe how specific spinal structures can change shape to permit movement between adjacent vertebrae.
#  → understand
#
# Question: Which structures fuse to form the median sacral crest?
#  → remember
#
# Question: Explain why structure fuse to form the median sacral crest?
#  → understand
#
# Question: The S2 vertebral body is a landmark for what structure?
#  → remember
#
# Question: Knee-jerk reflex is an example of what type of response?
#  → remember
#
# Question: Explain what type of repsonse the the knee jerk reflex is ?
#  → understand
#
# Question: A clinician taps a patientÕs patellar tendon to test reflex function. What type of response should normally occur, and what does it indicate about the neural pathway involved?
#  → understand
#
# Question: Which motor response does NOT involve a ganglion?
#  → remember
#
# Question: Explain why some motor responses  equire ganglia while other do not.
#  → understand
#
# Question: A patient shows impaired autonomic function but normal voluntary movement. Which type of motor pathway is still functioning normally, and why does it not require a ganglion?
#  → understand
#
# Question: Where do sensory fibres carrying low blood oxygen information travel?
#  → remember
#
# Question: A patient has damage to the nerve that carries sensory information about low blood oxygen. Which pathway would be disrupted, and how would this affect the bodyÕs response to hypoxia?
#  → understand
#
# Question: What happens to thoracic vertical dimension when the diaphragm contracts?
#  → remember
#
# Question: Explain how contraction of the diaphragm changes the vertical dimension of the thoracic cavity.
#  → understand
#
# Question: A patient takes a deep breath during a physical exam. How does contraction of the diaphragm alter the size of the thoracic cavity to allow this inhalation?
#  → understand
#
# Question: What articulates with the superior costal facet of T4?
#  → remember
#
# Question: What causes blunting of the costodiaphragmatic angle on X-ray?
#  → remember
#
# Question: A patientÕs chest X-ray shows a blunted costodiaphragmatic angle. What condition does this suggest?
#  → remember
#
# Question: What normally occupies the costodiaphragmatic recess?
#  → remember
#
# Question: A physician suspects pleural effusion. How would the normal contents of the costodiaphragmatic recess help determine whether pleural effusion is present?
#  → understand
#
# Question: What is the correct airway order during bronchoscopy?
#  → remember
#
# Question: The cardiac notch is a feature of which lung lobe?
#  → remember
#
# Question: Explain why the cardiac notch appears on one lung.
#  → understand
#
# Question: A clinician is assessing a chest X-ray and notices a clear indentation created by the heart. Which lung lobe does this correspond to, and why does the heart create this shape?
#  → understand
#
# Question: What forms the anterior surface of the heart?
#  → remember
#
# Question: Fluid in the pericardial cavity with hypotension and JVD requires what treatment?
#  → apply
#
# Question: A patient presents with hypotension, jugular venous distension, and fluid in the pericardial cavity. What treatment is required to relieve the pressure on the heart?
#  → apply
#
# Question: S2 heart sound results from closure of which valves?
#  → remember
#
# Question: A posterior esophageal puncture at T3 risks injuring what vessel?
#  → remember
#
# Question: During a procedure near the posterior esophagus at the level of T3, which nearby vessel is at risk of being damaged?
#  → remember
#
# Question: A midline thymic tumor compressing a posterior vessel most likely affects which vessel?
#  → remember
#
# Question: A patient has a midline thymic tumor that is growing posteriorly. Which vessel is most likely to be compressed.
#  → apply
#
# Question: Which heart chamber is most closely associated with the esophagus?
#  → remember
#
# Question: A physician is assessing a posterior mediastinal mass that is displacing the esophagus. Which heart chamber would likely be affected as well.
#  → apply
#
# Question: To which region of the abdomen does pain from a gastric ulcer refer?
#  → remember
#
# Question: A patient with a gastric ulcer reports abdominal pain. Which region would you expect the pain to be referred to?
#  → remember
#
# Question: What is the linea alba?
#  → remember
#
# Question: Explain the structure and anatomical role of the linea alba in the anterior abdominal wall.
#  → understand
#
# Question: A surgeon plans a midline abdominal incision. How does the structure of the linea alba make this location advantageous for entering the abdominal cavity?
#  → understand
#
# Question: What describes a direct inguinal hernia?
#  → remember
#
# Question: Explain how a direct inguinal hernia forms?
#  → understand
#
# Question: A patient presents with a bulge medial to the epigastric artery, what type of inghuinal hernia does this represent?
#  → remember
#
# Question: During descent of the testes, which layer is NOT passed through?
#  → remember
#
# Question: Explain how the testes pass through specific abdominal wall layers during their descent into the scrotum.
#  → understand
#
# Question: Which layer gives rise to the tunica vaginalis testis?
#  → remember
#
# Question: Which structures are derived from the ventral mesentery?
#  → remember
#
# Question: Explain how the ventral mesentery gives rise to certain abdominal structures during development.
#  → understand
#
# Question: A developmental anomaly affects organs formed from the ventral mesentery. Which structures would be involved, and why?
#  → understand
#
# Question: Which artery arises from the superior mesenteric artery?
#  → remember
#
# Question: Describe how the superior mesenteric artery branches to supply portions of the foregut, midgut, hindgut.
#  → understand
#
# Question: A clinician is tracing blood supply to the midgut. Which branch should they expect to originate from the superior mesenteric artery?
#  → apply
#
# Question: Which organ adheres anteriorly to the pancreas in chronic pancreatitis?
#  → remember
#
# Question: A patient with chronic pancreatitis develops adhesions on the anterior surface of the pancreas. Which nearby organ is most likely involved?
#  → apply
#
# Question: Which digestive subdivision has the tallest villi?
#  → remember
#
# Question: Explain why villus height differs among regions of the small intestine.
#  → understand
#
# Question: A clinician examines a biopsy showing very tall intestinal villi. Which part of the small intestine is the sample most likely from, and why?
#  → understand
#
# Question: Descending colon cancer first metastasizes to which lymph nodes?
#  → remember
#
# Question: Explain how lymphatic drainage from the descending colon determines the first lymph nodes involved in metastasis.
#  → understand
#
# Question: A patient is diagnosed with descending colon cancer. Based on its lymphatic drainage pattern, which lymph nodes would you expect to be the first site of metastasis, and why?
#  → understand
#
# Question: Which is inconsistent with appendicitis?
#  → remember
#
# Question: Gastro-omental arteries are associated with which stomach region?
#  → remember
#
# Question: Describe how the gastro-omental arteries relate to the curvature of the stomach.
#  → understand
#
# Question: A surgeon is operating near the greater curvature of the stomach. Which arteries should they expect to encounter there, and why?
#  → understand
#
# Question: The tail of the pancreas is most closely associated with which structure?
#  → remember
#
# Question: To which structure is the bare area of the liver attached?
#  → remember
#
# Question: Explain why the bare area of the liver remains uncovered by peritoneum and how it maintains attachment within the abdominal cavity.
#  → understand
#
# Question: A patient has trauma affecting the region where the liver directly contacts the diaphragm. Which structure is involved?
#  → apply
#
# Question: Which mix in hepatic sinusoids?
#  → remember
#
# Question: Explain how different sources of blood combine within hepatic sinusoids.
#  → understand
#
# Question: A patient has reduced oxygen delivery to their liver. Which two blood supplies normally mix in the hepatic sinusoids, and how would impairment of one source affect overall liver function
#  → understand
#
# Question: Which structures unite to form the bile duct?
#  → remember
#
# Question: Explain how different ducts from the liver and gallbladder join together to form the bile duct.
#  → understand
#
# Question: Which organ is most at risk of varices due to portal hypertension?
#  → remember
#
# Question: Explain why increased pressure in the portal venous system can lead to varices in specific abdominal organs.
#  → understand
#
# Question: A patient with portal hypertension develops enlarged veins in the digestive tract. Which organ is most susceptible to varices in this condition, and why?
#  → understand
#
# Question: What are the openings at the tip of each renal papilla?
#  → remember
#
# Question: How much filtered fluid becomes urine?
#  → remember
#
# Question: Where is the true pelvis located?
#  → remember
#
# Question: Describe how the features f the pelvis differentiate the true pelvis from the false pelvis.
#  → understand
#
# Question: What converts the greater sciatic notch to the greater sciatic foramen?
#  → remember
#
# Question: Explain how a ligament transforms the greater sciatic notch into a foramen
#  → understand
#
# Question: Which differentiates a male pelvis from a female pelvis?
#  → remember
#
# Question: Describe the key anatomical differences between a male pelvis and a female pelvis.
#  → understand
#
# Question: A clinician is evaluating pelvic morphology on imaging. Which features would indicate that the pelvis belongs to a female, and why?
#  → understand
#
# Question: A laceration during childbirth affects which pelvic diaphragm muscle?
#  → remember
#
# Question: Explain which pelvic diaphragm muscles are most involved during childbirth and why one of them is especially vulnerable to tearing.
#  → understand
#
# Question: Pelvic splanchnic nerve input causes what bladder effect?
#  → remember
#
# Question: Damage to the prostatic plexus during prostatectomy causes what outcome?
#  → remember
#
# Question: A patient undergoes prostatectomy and subsequently develops erectile dysfunction. How does damage to the prostatic plexus during surgery lead to this outcome?
#  → understand
#
# Question: The apex of the prostate is closely related to which structure?
#  → remember
#
# Question: In females, which structure is derived from the gubernaculum?
#  → remember
#
# Question: Explain how the gubernaculum guides the development of reproductive structures in females.
#  → understand
#
# Question: Where does fertilization most likely occur in the uterine tube?
#  → remember

# %%
def compute_accuracy(true_labels, predicted_labels):
    correct = 0
    total = len(true_labels)

    for true_label, pred_label in zip(true_labels, predicted_labels):
        if true_label.strip().lower() == pred_label.strip().lower():
            correct += 1

    accuracy = correct / total
    print(f"Accuracy: {accuracy:.2%}")

    return accuracy

# %% [markdown]
# Now we compute the accuracy of our self made labeling for the antonomy test questions using the GPT evaluator.

# %%
accuracy = compute_accuracy(labels, gpt_labels)
# Out:
# Accuracy: 79.13%
# 0.7913043478260869

# %% [markdown]
# Now we compute the accuracy for each of the remmeber, understand, apply agents.

# %%
_, gpt_labels =classify_questions(remember_questions)
true_labels = ["remember"] * len(remember_questions)
accuracy = compute_accuracy(true_labels, gpt_labels)
# Out:
# Question: What are the four basic tissue types in the human body?
#  → remember
#
# Question: What component makes up most of the volume in connective tissue?
#  → remember
#
# Question: What type of connective tissue protein fibre provides tensile strength?
#  → remember
#
# Question: What is the typical size range of normal lymph nodes?
#  → remember
#
# Question: What are the three common components shared by all connective tissues?
#  → remember
#
# Question: What type of connective tissue has parallel collagen fibers that provide tensile strength along one axis, as found in tendons and ligaments?
#  → remember
#
# Question: What type of cell is found embedded in the extracellular matrix of cartilage?
#  → remember
#
# Question: What type of bone houses red bone marrow, the site of hematopoiesis?
#  → remember
#
# Question: What are the four basic types of tissue in the human body?
#  → remember
#
# Question: What is the main component that determines the properties of connective tissue?
#  → remember
#
# Question: What is the main function of collagen fibers in connective tissue?
#  → remember
#
# Question: What is the normal size range of lymph nodes?
#  → remember
#
# Question: From which embryonic tissue do connective tissue cells originate?
#  → remember
#
# Question: Which type of connective tissue contains parallel collagen fibers and provides tensile strength along one axis, such as in tendons and ligaments?
#  → remember
#
# Question: What type of cells are embedded in the extracellular matrix of cartilage?
#  → remember
#
# Question: What type of bone houses red bone marrow, the site of hematopoiesis?
#  → remember
#
# Question: What are the four basic tissue types in the human body?
#  → remember
#
# Question: What component makes up most of the volume in connective tissue?
#  → remember
#
# Question: What type of connective tissue protein fiber provides tensile strength?
#  → remember
#
# Question: What is the normal size range of lymph nodes in millimeters?
#  → remember
#
# Question: From which embryonic tissue do connective tissue cells originate?
#  → remember
#
# Question: What type of connective tissue contains parallel collagen fibres and provides tensile strength along one axis?
#  → remember
#
# Question: How many subtypes of cartilage are there?
#  → remember
#
# Question: What type of bone contains spaces that house red bone marrow, the site of hematopoiesis?
#  → remember
#
# Question: What are the four basic tissue types in the human body?
#  → remember
#
# Question: What type of cell produces and secretes protein fibres and organic components in connective tissue?
#  → remember
#
# Question: What type of protein fibre in connective tissue imparts tensile strength?
#  → remember
#
# Question: What is the normal size range of lymph nodes in millimeters?
#  → remember
#
# Question: What embryonic tissue gives rise to connective tissue cells?
#  → remember
#
# Question: What type of connective tissue contains densely packed collagen fibers arranged in parallel to provide tensile strength along one axis?
#  → remember
#
# Question: What type of cell is found embedded in the extracellular matrix of cartilage?
#  → remember
#
# Question: What type of bone tissue contains spaces that house red bone marrow?
#  → remember
#
# Question: What are the four basic types of tissue in the human body?
#  → remember
#
# Question: What component determines the properties of connective tissue such as being solid, rubbery, gelatinous, or liquid?
#  → remember
#
# Question: What type of protein fibre in connective tissue provides tensile strength?
#  → remember
#
# Question: What is the normal size range of lymph nodes in millimeters?
#  → remember
#
# Question: What embryonic tissue is the origin of connective tissue cells?
#  → remember
#
# Question: What type of connective tissue contains parallel collagen fibres and provides tensile strength along one axis?
#  → remember
#
# Question: What are the three subtypes of cartilage?
#  → remember
#
# Question: What type of bone marrow is housed in the spaces of spongy bone?
#  → remember
#
# Question: What are the four basic types of tissue in the human body?
#  → remember
#
# Question: What component of connective tissue determines whether it is solid, rubbery, gelatinous, or liquid?
#  → remember
#
# Question: What type of protein fibres in connective tissue provide tensile strength?
#  → remember
#
# Question: What is the normal size range of lymph nodes?
#  → remember
#
# Question: What are the three common components shared by all connective tissues?
#  → remember
#
# Question: What type of connective tissue is composed mostly of adipocytes and functions in energy storage?
#  → remember
#
# Question: What type of cells are embedded in the extracellular matrix of cartilage?
#  → remember
#
# Question: What type of bone contains spaces that house red bone marrow, the site of hematopoiesis?
#  → remember
#
# Question: What are the four basic tissue types in the human body?
#  → remember
#
# Question: What component makes up most of the volume in connective tissue?
#  → remember
#
# Question: What type of protein fibre in connective tissue imparts tensile strength?
#  → remember
#
# Question: What is the normal size range of lymph nodes?
#  → remember
#
# Question: What are the three common components shared by all connective tissues?
#  → remember
#
# Question: What type of connective tissue forms parallel fibres and provides tensile strength along one axis, such as in tendons and ligaments?
#  → remember
#
# Question: What cells are embedded within the extracellular matrix of cartilage?
#  → remember
#
# Question: What type of bone houses red bone marrow, the site of hematopoiesis?
#  → remember
#
# Question: What are the four basic tissue types in the human body?
#  → remember
#
# Question: What determines the properties of connective tissue?
#  → understand
#
# Question: What type of connective tissue fibre provides tensile strength?
#  → remember
#
# Question: What is the normal size range, in millimeters, for lymph nodes?
#  → remember
#
# Question: From which embryonic tissue do connective tissue cells originate?
#  → remember
#
# Question: What type of connective tissue has parallel collagen fibers that provide tensile strength along one axis and is found in tendons and ligaments?
#  → remember
#
# Question: What type of cell is embedded within the extracellular matrix of cartilage?
#  → remember
#
# Question: What type of bone tissue houses red bone marrow, the site of hematopoiesis?
#  → remember
#
# Question: What are the four basic tissue types in the human body?
#  → remember
#
# Question: What component makes up most of the volume in connective tissue?
#  → remember
#
# Question: What protein fibres provide resiliency in connective tissue?
#  → remember
#
# Question: What is the normal size range of lymph nodes in millimeters?
#  → remember
#
# Question: From what embryonic tissue do connective tissue cells originate?
#  → remember
#
# Question: What type of connective tissue has parallel collagen fibers providing tensile strength along one axis?
#  → remember
#
# Question: What type of cells are embedded within the extracellular matrix of cartilage?
#  → remember
#
# Question: What type of bone marrow is housed in the spaces of spongy bone?
#  → remember
#
# Question: What are the four basic tissue types in the human body?
#  → remember
#
# Question: What component makes up most of the volume in connective tissue?
#  → remember
#
# Question: What type of connective tissue protein fiber is responsible for providing tensile strength?
#  → remember
#
# Question: What is the normal size range of lymph nodes in millimeters?
#  → remember
#
# Question: From which embryonic tissue do connective tissue cells originate?
#  → remember
#
# Question: What type of connective tissue has parallel collagen fibers that provide tensile strength along one axis and is found in tendons and ligaments?
#  → remember
#
# Question: What type of cell is embedded within the extracellular matrix of cartilage?
#  → remember
#
# Question: What type of bone houses red bone marrow, the site of hematopoiesis?
#  → remember
#
# Question: What are the four basic types of tissue in the human body?
#  → remember
#
# Question: What type of cell produces and secretes protein fibres and organic components that form the ground substance in connective tissue?
#  → remember
#
# Question: What type of protein fibre in connective tissue imparts tensile strength?
#  → remember
#
# Question: What is the normal size range of lymph nodes?
#  → remember
#
# Question: From which embryonic tissue do connective tissue cells originate?
#  → remember
#
# Question: What type of connective tissue has parallel collagen fibres providing tensile strength along one axis?
#  → remember
#
# Question: What type of cells are embedded in the extracellular matrix of cartilage?
#  → remember
#
# Question: What type of bone houses red bone marrow, the site of hematopoiesis?
#  → remember
#
# Question: What are the four basic types of tissue in the human body?
#  → remember
#
# Question: What component makes up most of the volume in connective tissue?
#  → remember
#
# Question: What type of protein fibre in connective tissue provides tensile strength?
#  → remember
#
# Question: What is the normal size range, in millimeters, of a lymph node?
#  → remember
#
# Question: What is the embryological origin of connective tissue cells?
#  → remember
#
# Question: What type of connective tissue is composed mostly of adipocytes and is supported by a reticular fiber stroma?
#  → remember
#
# Question: What type of cells are embedded in the extracellular matrix of cartilage?
#  → remember
#
# Question: What type of bone houses red bone marrow, the site of hematopoiesis?
#  → remember
#
# Question: What are the four basic tissue types in the human body?
#  → remember
#
# Question: What primarily determines the properties of connective tissue?
#  → remember
#
# Question: What type of protein fibres in connective tissue provide tensile strength?
#  → remember
#
# Question: What is the normal size range of lymph nodes in millimeters?
#  → remember
#
# Accuracy: 99.00%

# %%
_, gpt_labels = classify_questions(understand_questions)
true_labels = ["understand"] * len(understand_questions)
accuracy = compute_accuracy(true_labels , gpt_labels)
# Out:
# Accuracy: 100.00%

# %%
_, gpt_labels = classify_questions(apply_questions)
true_labels = ["apply"] * len(apply_questions)
accuracy = compute_accuracy(true_labels, gpt_labels)
# Out:
# Accuracy: 40.00%

# %% [markdown]
# Now lets try one central agent that produces remember, understand, apply questions

# %%
system_prompt_three_level = """
You are an agent that generates questions at a specified Bloom’s Taxonomy level.
You will receive two inputs:
1. Raw text extracted from lecture slides.
2. A level request: "remember", "understand", or "apply".

Your task:
Create ONE question at the requested level based only on the information in the slide text.

Rules by level:

remember:
- Ask for simple factual recall.
- One clear factual answer.
- No explanation, interpretation, or scenario.

understand:
- Ask the learner to explain, describe, summarize, or interpret a concept.
- No application or problem-solving.
- Question should test comprehension of meaning or relationships.

apply:
- Ask the learner to use knowledge in a new but relevant situation.
- Create a simple scenario where the information must be applied.
- One logically deducible correct answer.
- No analysis or multi-step inference.

General rules:
- Do NOT reference “the slide” or “the text.”
- Use only information found in the input text.
- Keep the question clear, concise, and natural.
- If the slide text is sparse, choose any fact present and build the question around it.

Output:
Only the question.
"""

# %%
def generate_all_levels(raw_text_list, iterations=30, filename="three_level_agent_questions_labels.csv"):
    levels = ["remember", "understand", "apply"]
    all_questions = []

    with open(filename, "w", newline="") as f:
        writer = csv.writer(f)
        writer.writerow(["question", "label"])  # header

        for level in levels:

            for i in range(iterations):
                slide_text = raw_text_list[i % len(raw_text_list)]

                user_prompt = f"""
                  Slide text:
                  {slide_text}
                  Requested level: {level}
                  """

                response = client.chat.completions.create(
                    model="gpt-4.1",
                    messages=[
                        {"role": "system", "content": system_prompt_three_level},
                        {"role": "user", "content": user_prompt}
                    ]
                )

                question = response.choices[0].message.content.strip()

                writer.writerow([question, level])  # save immediately

                all_questions.append((question, level))

                print(f"[{level}] {i+1}/{iterations}: {question}")

        return all_questions

# %%
all_questions = generate_all_levels(raw_text_list, iterations=33, filename="three_level_agent_questions_labels.csv")
# Out:
# [remember] 1/33: What are the four basic tissue types in the human body?
# [remember] 2/33: What component determines the properties of connective tissue?
# [remember] 3/33: What type of protein fibre in connective tissue provides tensile strength?
# [remember] 4/33: What is the typical size range of normal lymph nodes?
# [remember] 5/33: What are the three common components shared by all connective tissues?
# [remember] 6/33: What type of connective tissue is composed mostly of adipocytes and is used for energy storage?
# [remember] 7/33: What type of cell is found embedded within cartilage?
# [remember] 8/33: What is the primary function of red bone marrow housed in the spaces of spongy bone?
# [remember] 9/33: What are the four basic tissue types in the human body?
# [remember] 10/33: What is the main component that determines the properties of connective tissue?
# [remember] 11/33: What is the main function of collagen fibres in connective tissue?
# [remember] 12/33: What is the normal size range of lymph nodes?
# [remember] 13/33: What embryonic tissue do connective tissue cells originate from?
# [remember] 14/33: What type of connective tissue is composed mostly of adipocytes and functions in energy storage?
# [remember] 15/33: What are the three subtypes of cartilage?
# [remember] 16/33: What type of bone houses red bone marrow, the site of hematopoiesis?
# [remember] 17/33: What are the four basic tissue types?
# [remember] 18/33: What component makes up most of the volume in connective tissue?
# [remember] 19/33: What is the name given to an increase in tissue fluid volume?
# [remember] 20/33: What is the normal size range of lymph nodes?
# [remember] 21/33: What are the three common components shared by all connective tissues?
# [remember] 22/33: What type of connective tissue has parallel collagen fibres that provide tensile strength along one axis?
# [remember] 23/33: What are the three subtypes of cartilage?
# [remember] 24/33: What type of bone tissue houses red bone marrow, the site of hematopoiesis?
# [remember] 25/33: What are the four basic tissue types in the human body?
# [remember] 26/33: What component makes up most of the volume in connective tissue?
# [remember] 27/33: What is the name for an increase in tissue fluid volume?
# [remember] 28/33: What is the normal size range of lymph nodes?
# [remember] 29/33: From what embryonic tissue do connective tissue cells originate?
# [remember] 30/33: Which type of connective tissue is composed mostly of adipocytes for energy storage and is highly vascular?
# [remember] 31/33: What are the three subtypes of cartilage?
# [remember] 32/33: What is the main type of fiber found in the organic component of bone matrix?
# [remember] 33/33: What are the four basic tissue types in the human body?
# [understand] 1/33: Explain how basic tissues contribute to the structure and function of organs.
# [understand] 2/33: Describe how the composition of the extracellular matrix influences the properties of different types of connective tissue.
# [understand] 3/33: Explain how the different components of the extracellular matrix work together to determine the properties and functions of connective tissue.
# [understand] 4/33: Explain how lymph nodes help limit the spread of disease and infection in the body.
# [understand] 5/33: Describe how differences in the type and proportion of cells, protein fibres, and ground substance influence the characteristics and functions of connective tissues.
# [understand] 6/33: Explain the structural differences between loose (areolar) connective tissue and dense connective tissue, and describe how these differences relate to their functions.
# [understand] 7/33: Explain how the structure and composition of cartilage enable it to withstand compressive forces while providing support to soft tissues.
# [understand] 8/33: Explain how the organic and inorganic components of bone matrix contribute to its overall strength and function.
# [understand] 9/33: Explain how the four basic tissue types contribute to the structure and function of organs.
# [understand] 10/33: Explain how differences in the composition and proportions of the extracellular matrix affect the properties of various types of connective tissue.
# [understand] 11/33: Explain how the composition of protein fibres in connective tissue influences its characteristics and function.
# [understand] 12/33: Explain how lymph nodes help limit the spread of disease and infection in the body.
# [understand] 13/33: Describe how the variation in type and proportion of cells, protein fibers, and ground substance influences the characteristics and functions of different connective tissue types.
# [understand] 14/33: Explain the differences between dense regular and dense irregular connective tissue in terms of their fiber arrangement and the type of strength they provide.
# [understand] 15/33: Explain how the properties of the extracellular matrix contribute to the function of cartilage in the body.
# [understand] 16/33: Explain how the organic and inorganic components of bone matrix contribute to the overall strength and function of bone.
# [understand] 17/33: Explain how the four basic tissue types contribute to the formation and function of organs in the human body.
# [understand] 18/33: Explain how variations in the composition and proportions of the extracellular matrix (ECM) contribute to the differences among types of connective tissues.
# [understand] 19/33: Explain how the roles of collagen fibres and elastic fibres differ in connective tissue.
# [understand] 20/33: Explain how lymph nodes help prevent the spread of disease and infection in the body.
# [understand] 21/33: Explain how the variation in the type and proportion of cells, protein fibres, and ground substance influences the characteristics and functions of different connective tissue types.
# [understand] 22/33: Explain how the structural differences between dense regular and dense irregular connective tissue relate to their functions in the body.
# [understand] 23/33: Explain how the properties of the extracellular matrix enable cartilage to withstand compressive forces.
# [understand] 24/33: Explain how the organic and inorganic components of bone matrix contribute to the strength and function of bone.
# [understand] 25/33: Describe how the four basic tissue types contribute to the formation of organs with distinct structure and function.
# [understand] 26/33: Explain how the composition of the extracellular matrix (ECM) influences the properties of different types of connective tissue.
# [understand] 27/33: Explain how the different components of the extracellular matrix contribute to the overall properties and function of connective tissue.
# [understand] 28/33: Explain how lymph nodes help limit the spread of disease and infection in the body.
# [understand] 29/33: Explain how the variation in type and proportion of cells, protein fibres, and ground substance influences the characteristics and functions of different connective tissues.
# [understand] 30/33: Explain how the structure of dense regular connective tissue is related to its function in the body.
# [understand] 31/33: Explain how the properties of cartilage's extracellular matrix contribute to its ability to withstand compressive forces.
# [understand] 32/33: Explain how the organic and inorganic components of bone matrix contribute to the overall strength and function of bone.
# [understand] 33/33: Explain how differentiation contributes to the formation of multiple cell types in the human body and why this is important for the organization of tissues and organs.
# [apply] 1/33: A researcher wants to investigate how damage to neural tissue in the brain might affect organ function. Based on the role of basic tissue types, which aspect of organ structure and function should the researcher focus on to study the impact of neural tissue damage?
# [apply] 2/33: A patient suffers an injury that causes the gelatinous part of their connective tissue to become more solid and rigid. Based on the components of connective tissue, which aspect of the tissue has likely changed to account for this difference?
# [apply] 3/33: A patient develops swelling in their ankles due to an increase in tissue fluid volume. What is the term used to describe this condition?
# [apply] 4/33: A physician palpates an enlarged lymph node in a patient's neck and suspects an infection in nearby tissues. Based on how the lymphatic system functions, explain why this lymph node is enlarged and what this indicates about the drainage and filtering process occurring in the area.
# [apply] 5/33: A patient has tissue that contains a high proportion of protein fibres and relatively little ground substance. Based on this information, how would you expect the characteristics and function of this connective tissue to differ from one with more ground substance and fewer fibres?
# [apply] 6/33: A patient suffers from a tear in a structure that requires great tensile strength in one direction, such as a ligament. Which type of connective tissue would be most important in repairing this structure?
# [apply] 7/33: A patient sustains a knee injury that leads to cartilage damage. Based on the properties of cartilage, explain why the healing process is likely to be slow or incomplete in this tissue.
# [apply] 8/33: A patient is experiencing frequent bone fractures due to decreased compressional strength in their bones. Based on the components of bone matrix, which mineral is most likely deficient, and why would this deficiency affect compressional strength?
# [apply] 9/33: A researcher observes a group of structurally and functionally similar cells that produce electrical impulses within the brain. To which of the four basic tissue types do these cells most likely belong?
# [apply] 10/33: A patient’s connective tissue injury results in a defect where the cells can no longer secrete protein fibres. Based on how connective tissue is structured, what primary change would you expect in the properties of their extracellular matrix?
# [apply] 11/33: A patient has swelling in their ankles due to an increased volume of tissue fluid. Based on the roles of connective tissue components, what property of the ground substance helps resist this swelling, and why?
# [apply] 12/33: A physician detects enlarged lymph nodes in a patient's axillae during an exam. Based on this finding, what might this indicate about the patient's immune activity or potential disease/infection in that region?
# [apply] 13/33: A patient has a tissue sample containing cells surrounded by abundant ground substance and protein fibres, but the cells are derived from mesenchyme rather than typical epithelial origins. Based on this information, how would you classify this type of tissue?
# [apply] 14/33: A patient has a torn ligament. Based on the structure and function of connective tissues, which type of connective tissue is primarily damaged, and what property does it contribute to the ligament?
# [apply] 15/33: A patient tears a piece of cartilage in their knee during a sports injury. Based on the characteristics of cartilage, what aspect of its structure explains why the recovery is likely to be slow?
# [apply] 16/33: A patient has a genetic disorder that leads to abnormally low collagen production in bone tissue. Based on this information, which mechanical property of their bones is most likely to be reduced, and why?
# [apply] 17/33: If a researcher is investigating how muscle contraction occurs at the tissue level, which of the four basic tissue types should they primarily examine, and why?
# [apply] 18/33: A tissue sample shows a gelatinous consistency and contains cells that secrete protein fibres and organic molecules into an extracellular matrix. How would you classify the primary type of tissue, and what component is most responsible for its consistency?
# [apply] 19/33: A patient develops edema, resulting in increased tissue fluid volume in their connective tissue. Based on the components of connective tissue described, which component’s properties most directly help resist the compressive forces from this excess fluid, and why is this the case?
# [apply] 20/33: A patient presents with enlarged, palpable lymph nodes in the axillae after a localized skin infection on their arm. Using your knowledge of lymphatic drainage, explain why these lymph nodes are likely affected.
# [apply] 21/33: A patient has a tissue sample showing surface lining cells that are embryologically derived from connective tissue rather than epithelial tissue. Based on this information, which type of cell is most likely present in the sample: epithelial, endothelial, or muscle?
# [apply] 22/33: A patient suffers a torn tendon during a sports injury. Based on the types of connective tissue described, which type of connective tissue is primarily affected by this injury, and what property does this tissue provide to the tendon?
# [apply] 23/33: A patient sustains an injury to their cartilage, resulting in a tear. Based on the properties of cartilage, explain why healing of this injury would likely be slow or incomplete.
# [apply] 24/33: A patient has a deficiency in calcium and phosphate intake. Based on the role of these minerals in bone matrix, what specific property of bone would likely be most affected, and why?
# [apply] 25/33: A pathologist is examining a biopsy sample and needs to identify which tissue type is responsible for transmitting electrical impulses. Based on the four basic tissue types, which one should the pathologist focus on?
# [apply] 26/33: If a connective tissue has a primarily rubbery consistency, which component of the tissue is most responsible for this property, and how would changing that component affect the tissue’s function?
# [apply] 27/33: A patient experiences excessive swelling in their ankle due to an increase in tissue fluid volume. Based on the roles of connective tissue components, which substance is primarily responsible for resisting this compression, and why might swelling still occur if that substance is overwhelmed?
# [apply] 28/33: A physician palpates a patient's neck and notices enlarged lymph nodes. Based on the function of lymph nodes described, what could this enlargement indicate about the patient's health?
# [apply] 29/33: A tissue sample contains cells, protein fibres, and ground substance, but the proportions of these components differ significantly from those in another sample. How would these differences affect the characteristics and functions of each tissue?
# [apply] 30/33: A physician is examining tissue from a tendon and observes that the collagen fibers are densely packed and arranged in parallel bundles. Based on this information, which type of connective tissue is the physician observing?
# [apply] 31/33: A patient has a joint injury that needs to withstand compressive forces but also requires slow healing due to limited blood supply. Based on these characteristics, which tissue type is most likely involved in the injury?
# [apply] 32/33: A patient has a genetic defect that reduces the production of collagen fibers in osteoid. Based on this information, which specific characteristic of their bones is most likely to be compromised: tensile strength, compressional strength, or mineral reservoir function?
# [apply] 33/33: A pathologist is examining a sample and identifies it as containing mainly structurally and functionally similar cells that transmit electrical impulses. Which basic tissue type is most likely being observed?

# %%
remember_questions  = [q for q, lbl in all_questions if lbl == "remember"]
understand_questions = [q for q, lbl in all_questions if lbl == "understand"]
apply_questions     = [q for q, lbl in all_questions if lbl == "apply"]

# %%
_, gpt_labels = classify_questions(remember_questions)
true_labels = ["remember"] * len(remember_questions)

remember_accuracy = compute_accuracy(true_labels, gpt_labels)
print(f"Remember Accuracy: {remember_accuracy:.2%}")
# Out:
# Accuracy: 100.00%
# Remember Accuracy: 100.00%

# %%
_, gpt_labels = classify_questions(understand_questions)
true_labels = ["understand"] * len(understand_questions)

understand_accuracy = compute_accuracy(true_labels, gpt_labels)
print(f"Understand Accuracy: {understand_accuracy:.2%}")
# Out:
# Accuracy: 100.00%
# Understand Accuracy: 100.00%

# %%
_, gpt_labels = classify_questions(apply_questions)
true_labels = ["apply"] * len(apply_questions)

apply_accuracy = compute_accuracy(true_labels, gpt_labels)
print(f"Apply Accuracy: {apply_accuracy:.2%}")
# Out:
# Accuracy: 51.52%
# Apply Accuracy: 51.52%
